# %%
# -*- coding: utf-8 -*-
#Created on Sun Dec 22 17:23:19 2019 @author: NOOR
import  os,shutil
import cv2
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
from keras.models import Input, Model
from keras.layers import BatchNormalization, LeakyReLU, Conv2D, Dense, \
                         Flatten, Add, PReLU, Conv2DTranspose, Lambda, UpSampling2D                    
from keras.optimizers import Adam
from keras.applications import VGG19
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf


tf.config.experimental.set_visible_devices([],'GPU')
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

classifier= Sequential()

classifier.add(Convolution2D(32,3,3,input_shape=(64,64,3),activation='relu'))

classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Convolution2D(32,3,3,activation='relu'))

classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Flatten())

classifier.add(Dense(output_dim=128,activation='relu')) 

classifier.add(Dense(output_dim=1,activation='sigmoid')) 

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('dataset/training_set',
        target_size=(64,64),
        batch_size=4,
        class_mode='binary')

test_set = test_datagen.flow_from_directory(
        'dataset/test_set',
        target_size=(64,64),
        batch_size=4,
        class_mode='binary')

classifier.fit_generator(
        training_set,
        steps_per_epoch=80,
        epochs=25,
        validation_data=test_set,
        validation_steps=20)

#classifier.evaluate()
#classifier.save('training_process.h5')

"""
from PIL import Image
from numpy import array
img=Image.open("input.png")
arr=array(img)
img=Image.fromarray(arr)
img.save("output.png")


os.listdir('images')

classifier.summary()

ls

shutil.move('/content/classifier_weights_epoch_1.h5', os.getcwd())

# classifier.srgan.load_weights('srgan_weights_epoch_1.h5')
#classifier.train(500, save_interval=20 ,batch_size=16)

# Load pretrained model
model_srgan.srgan.load_weights('srgan_weights_epoch_450.h5')
plot_predict(low_reso_imgs,high_reso_imgs,model_srgan)

plt.imshow(testimg)

def predict_on_test(image):
  plt.figure(figsize = (64,64))
  plt.tight_layout()
  plt.grid('off')
  plt.axis('off')
  plt.title('Source')
  plt.imshow(cv2.resize(image,(64,64),
                    interpolation = cv2.INTER_CUBIC))
  plt.grid('off')
  plt.axis('off')
  plt.title('X4 (bicubic)')  
  img = classifier.predict(np.expand_dims(image, axis = 0) / 127.5 - 1)
  img_unnorm = (img+1) * 127.5
  plt.subplot(n_imgs,3,i+3)
  plt.imshow(np.squeeze(img_unnorm, axis = 0).astype(np.uint8))
  plt.grid('off')
  plt.axis('off')
  plt.title('classifier')
        
  plt.de('predicted.png')



def preprocess(path):
  img = cv2.imread(path)
  #img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  #img_crop = crop_center(img,64,64)
  #return cv2.resize(img_crop, (64, 64))

path = '/input.png'
plt.imshow(preprocess(path))

def infer(path):
  image = preprocess(path)
  print(image.shape)
  img = classifier.predict(np.expand_dims(image, axis = 0) / 127.5 - 1)
  plt.imshow(np.squeeze(img))

infer(path)
"""
